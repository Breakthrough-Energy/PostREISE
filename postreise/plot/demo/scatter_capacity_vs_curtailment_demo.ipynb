# %%
from powersimdata.utility.helpers import PrintManager
from powersimdata.scenario.scenario import Scenario

from postreise.plot.plot_scatter_capacity_vs_curtailment import plot_scatter_capacity_vs_curtailment

# %% [markdown]
# ### Scatter Plot

# %%
with PrintManager():
    scenario = Scenario(1270)

# %%
with PrintManager():
    plot_scatter_capacity_vs_curtailment(
        scenario, 
        "all", 
        "wind"
    )
    plot_scatter_capacity_vs_curtailment(
        scenario, 
        "all", 
        "wind",
        percentage=True
    )

# %%
with PrintManager():
    _, data_avg = plot_scatter_capacity_vs_curtailment(
        scenario, 
        "all", 
        "solar", 
        time_zone="Etc/GMT+8",
        between_time=["00:00", "01:00"]
    )

# %%
data_avg
# Out:
# 0.0
