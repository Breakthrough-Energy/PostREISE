# %% [markdown]
# # Transmission Upgrades Map

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import output_file, save
from powersimdata import Scenario
from powersimdata.utility.helpers import PrintManager

from postreise.plot.plot_transmission_upgrades_map import map_transmission_upgrades

# %% [markdown]
# We use here two Western scenarios. Both have same generation but one has transmission upgrade.

# %%
with PrintManager():
    scenarioA = Scenario(2497)
    scenarioB = Scenario(3101)
    
    upgrades_map = map_transmission_upgrades(
        scenarioA, 
        scenarioB, 
        b2b_indices=range(9))

output_notebook()
show(upgrades_map)
# Out:
# 100%|##########| 664k/664k [00:00<00:00, 2.99Mb/s]
# 100%|##########| 50.0k/50.0k [00:00<00:00, 833kb/s]
# 100%|##########| 664k/664k [00:00<00:00, 2.90Mb/s]
# 100%|##########| 664k/664k [00:00<00:00, 2.69Mb/s]
# 100%|##########| 50.0k/50.0k [00:00<00:00, 880kb/s]
# 100%|##########| 664k/664k [00:00<00:00, 2.97Mb/s]
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1093">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="f3a65b8e-7f70-45d4-8dad-1e14f6b16156" data-root-id="1001"></div>
