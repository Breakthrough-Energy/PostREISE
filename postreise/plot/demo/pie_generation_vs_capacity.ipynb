# %%
from powersimdata.utility.helpers import PrintManager

from postreise.plot.plot_pie_generation_vs_capacity import plot_pie_generation_vs_capacity

# %% [markdown]
# ### Pie Plot

# %%
with PrintManager():
    plot_pie_generation_vs_capacity(
        areas=["all", "Western", "Texas", "Eastern"], 
        area_types=[None, None, "interconnect", None], 
        scenario_ids=[823, 824],
        scenario_names=["USA 2016", "USA 2020"],
        min_percentage=2.5
    )
# Out:
# 100%|##########| 455k/455k [00:00<00:00, 206kb/s]
# 100%|##########| 40.2k/40.2k [00:00<00:00, 73.6kb/s]
# 100%|##########| 455k/455k [00:01<00:00, 171kb/s]
# 100%|##########| 40.2k/40.2k [00:00<00:00, 76.6kb/s]
