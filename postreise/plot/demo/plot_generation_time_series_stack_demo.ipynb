# %%
from powersimdata.scenario.scenario import Scenario
from postreise.plot.plot_generation_ts_stack import plot_generation_time_series_stack

# %%
t2c = {
    "nuclear": "#173FA5",
    "hydro": "#0090FF",
    "geothermal": "#CC67F3",
    "other": "#8B36FF",
    "dfo": "#31E8CB",
    "coal": "#37404C",
    "ng": "#72818F",
    "solar": "#FFBB45",
    "wind": "#78D911",
    "solar_curtailment": "#FFBB45",
    "wind_curtailment": "#78D911",
}

t2l = {
    "nuclear": "Nuclear",
    "hydro": "Hydro",
    "geothermal": "Geothermal",
    "other": "Other",
    "dfo": "Distillate Fuel Oil",
    "coal": "Coal",
    "ng": "Natural Gas",
    "solar": "Solar",
    "wind": "Wind",
    "wind_offshore": "Wind Offshore",
    "biomass": "Biomass",
    "storage": "Storage",
    "solar_curtailment": "Solar Curtailment",
    "wind_curtailment": "Wind Curtailment",
    "wind_offshore_curtailment": "Offshore Wind Curtailment",
}

t2hc = {
    "solar_curtailment": "#996100",
    "wind_curtailment": "#4e8e0b"
}

# %%
s_texas = Scenario(1150)
# Out:
# 0.00b [00:00, ?b/s]
# Transferring ScenarioList.csv from server
# 100%|##########| 242k/242k [00:01<00:00, 230kb/s]
# 0.00b [00:00, ?b/s]
# Transferring ExecuteList.csv from server
# 100%|##########| 21.7k/21.7k [00:00<00:00, 39.4kb/s]
# SCENARIO: Julia | Texas2030Storage_OB0.5_Mesh20x7
#
# --> State
# analyze
# --> Loading grid
# Loading bus
# Loading plant
# Loading heat_rate_curve
# Loading gencost_before
# Loading gencost_after
# Loading branch
# Loading sub
# Loading bus2sub
# --> Loading ct

# %%
resources = [
    "nuclear",
    "coal",
    "hydro",
    "geothermal",
    "other",
    "dfo",
    "ng",
    "solar",
    "wind",
    "storage",
    "solar_curtailment",
    "wind_curtailment",
]
plot_generation_time_series_stack(s_texas, "Texas", resources, time_freq="D", normalize=True, t2c=t2c, t2l=t2l, t2hc=t2hc)
# Out:
# --> Loading PG
# Reading bus.csv
# Reading plant.csv
# Reading gencost.csv
# Reading branch.csv
# Reading dcline.csv
# Reading sub.csv
# Reading bus2sub.csv
# Reading zone.csv
# --> Loading demand
# Multiply demand in West (#303) by 1.36
# Multiply demand in North (#302) by 1.36
# Multiply demand in South Central (#306) by 1.36
# Multiply demand in Coast (#307) by 1.36
# Multiply demand in Far West (#301) by 1.36
# Multiply demand in East (#308) by 1.36
# Multiply demand in North Central (#305) by 1.36
# Multiply demand in South (#304) by 1.36
# --> Loading PG
# --> Loading demand
# Multiply demand in West (#303) by 1.36
# Multiply demand in North (#302) by 1.36
# Multiply demand in South Central (#306) by 1.36
# Multiply demand in Coast (#307) by 1.36
# Multiply demand in Far West (#301) by 1.36
# Multiply demand in East (#308) by 1.36
# Multiply demand in North Central (#305) by 1.36
# Multiply demand in South (#304) by 1.36
# --> Loading PG
# --> Loading wind
# --> Loading solar
# ...

# %%
s_usa = Scenario(1270)
# Out:
# 0.00b [00:00, ?b/s]
# Transferring ScenarioList.csv from server
# 100%|##########| 242k/242k [00:01<00:00, 234kb/s]
# 0.00b [00:00, ?b/s]
# Transferring ExecuteList.csv from server
# 100%|##########| 21.7k/21.7k [00:00<00:00, 39.5kb/s]
# SCENARIO: Julia | USA2030HVDC_Design3_OB1_Mesh500x38
#
# --> State
# analyze
# --> Loading grid
# Loading bus
# Loading plant
# Loading heat_rate_curve
# Loading gencost_before
# Loading gencost_after
# Loading branch
# Loading dcline
# Loading sub
# Loading bus2sub
# --> Loading ct

# %%
resources = [
    "nuclear",
    "hydro",
    "geothermal",
    "other",
    "dfo",
    "coal",
    "ng",
    "solar",
    "wind",
    "solar_curtailment",
    "wind_curtailment",
]
plot_generation_time_series_stack(s_usa, "all", resources, time_freq="D", normalize=True, t2c=t2c, t2l=t2l, t2hc=t2hc, title="USA")
# Out:
# --> Loading PG
# Reading bus.csv
# Reading plant.csv
# Reading gencost.csv
# Reading branch.csv
# Reading dcline.csv
# Reading sub.csv
# Reading bus2sub.csv
# Reading zone.csv
# --> Loading demand
# Multiply demand in Maine (#1) by 0.95
# Multiply demand in New Hampshire (#2) by 0.95
# Multiply demand in Vermont (#3) by 0.95
# Multiply demand in Massachusetts (#4) by 0.95
# Multiply demand in Rhode Island (#5) by 0.95
# Multiply demand in Connecticut (#6) by 0.95
# Multiply demand in New York City (#7) by 0.98
# Multiply demand in Upstate New York (#8) by 0.98
# Multiply demand in New Jersey (#9) by 1.15
# Multiply demand in Pennsylvania Eastern (#10) by 1.09
# Multiply demand in Pennsylvania Western (#11) by 1.09
# Multiply demand in Delaware (#12) by 1.17
# Multiply demand in Maryland (#13) by 1.03
# Multiply demand in Virginia Mountains (#14) by 1.21
# Multiply demand in Virginia Tidewater (#15) by 1.21
# Multiply demand in North Carolina (#16) by 1.15
# ...

# %%
s_eastern = Scenario(585)
# Out:
# 0.00b [00:00, ?b/s]
# Transferring ScenarioList.csv from server
# 100%|##########| 242k/242k [00:01<00:00, 230kb/s]
# 0.00b [00:00, ?b/s]
# Transferring ExecuteList.csv from server
# 100%|##########| 21.7k/21.7k [00:00<00:00, 38.8kb/s]
# SCENARIO: Julia | Eastern2030CollaborativeOffshore_Mandate_OB2_Mesh200x2
#
# --> State
# analyze
# --> Loading grid
# Loading bus
# Loading plant
# Loading heat_rate_curve
# Loading gencost_before
# Loading gencost_after
# Loading branch
# Loading dcline
# Loading sub
# Loading bus2sub
# --> Loading ct

# %%
resources = [
    "nuclear",
    "hydro",
    "geothermal",
    "other",
    "dfo",
    "coal",
    "ng",
    "solar",
    "wind",
    "wind_offshore",
    "solar_curtailment",
    "wind_curtailment",
    "wind_offshore_curtailment",
]
plot_generation_time_series_stack(s_eastern, "all", resources, time_freq="D", normalize=True, t2c=t2c, t2l=t2l, t2hc=t2hc, title="Eastern")
# Out:
# --> Loading PG
# Reading bus.csv
# Reading plant.csv
# Reading gencost.csv
# Reading branch.csv
# Reading dcline.csv
# Reading sub.csv
# Reading bus2sub.csv
# Reading zone.csv
# --> Loading demand
# Multiply demand in Maine (#1) by 0.95
# Multiply demand in New Hampshire (#2) by 0.95
# Multiply demand in Vermont (#3) by 0.95
# Multiply demand in Massachusetts (#4) by 0.95
# Multiply demand in Rhode Island (#5) by 0.95
# Multiply demand in Connecticut (#6) by 0.95
# Multiply demand in New York City (#7) by 0.98
# Multiply demand in Upstate New York (#8) by 0.98
# Multiply demand in New Jersey (#9) by 1.15
# Multiply demand in Pennsylvania Eastern (#10) by 1.09
# Multiply demand in Pennsylvania Western (#11) by 1.09
# Multiply demand in Delaware (#12) by 1.17
# Multiply demand in Maryland (#13) by 1.03
# Multiply demand in Virginia Mountains (#14) by 1.21
# Multiply demand in Virginia Tidewater (#15) by 1.21
# Multiply demand in North Carolina (#16) by 1.15
# ...
