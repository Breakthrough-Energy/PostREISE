# %%
from powersimdata import Scenario
from powersimdata.utility.helpers import PrintManager

from postreise.plot.plot_bar_renewable_max_profile_actual import plot_bar_renewable_max_profile_actual

# %% [markdown]
# ### Bar plot

# %%
with PrintManager():
    scenario = Scenario("1270")
    plot_bar_renewable_max_profile_actual(scenario, "USA", "wind", show_as_state=True, percentage=False)
    plot_bar_renewable_max_profile_actual(scenario, "Western", "solar", show_as_state=True, percentage=True)
    plot_bar_renewable_max_profile_actual(scenario, "Texas", "wind", show_as_state=False, percentage=False)
