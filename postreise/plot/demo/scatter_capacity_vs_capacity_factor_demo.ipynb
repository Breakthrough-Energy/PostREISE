# %%
from powersimdata.utility.helpers import PrintManager
from powersimdata.scenario.scenario import Scenario

from postreise.plot.plot_scatter_capacity_vs_capacity_factor import plot_scatter_capacity_vs_capacity_factor

# %% [markdown]
# ### Scatter Plot

# %%
with PrintManager():
    scenario = Scenario(823)

# %%
with PrintManager():
    plot_scatter_capacity_vs_capacity_factor(
        scenario, 
        "Western", 
        "solar"
    )
    plot_scatter_capacity_vs_capacity_factor(
        scenario, 
        "Western", 
        "solar",
        percentage=True
    )

# %%
_, data_avg = plot_scatter_capacity_vs_capacity_factor(
    scenario, 
    "Western", 
    "solar", 
    time_zone="Etc/GMT+8",
    between_time=["00:00", "01:00"]
)
# Out:
# --> Loading PG

# %%
data_avg
# Out:
# 0.0
