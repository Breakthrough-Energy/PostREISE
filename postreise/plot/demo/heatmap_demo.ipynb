# %% [markdown]
# # Heatmap of Curtailment

# %%
import matplotlib.pyplot as plt
import powersimdata as psd
from powersimdata.scenario.scenario import Scenario

from postreise.analyze.generation.curtailment import calculate_curtailment_time_series
from postreise.plot.plot_heatmap import plot_heatmap

# %%
scenario = Scenario(1270)
summed_curtailment = calculate_curtailment_time_series(scenario).sum(axis=1)
# Out:
#  59%|#####9    | 393k/664k [00:00<00:00, 3.85Mb/s]
# Transferring ScenarioList.csv from server
# 100%|##########| 664k/664k [00:00<00:00, 3.07Mb/s]
# 100%|##########| 50.0k/50.0k [00:00<00:00, 764kb/s]
# Transferring ExecuteList.csv from server
# SCENARIO: Julia | USA2030HVDC_Design3_OB1_Mesh500x38
#
# --> State
# analyze
# --> Loading grid
#  59%|#####9    | 393k/664k [00:00<00:00, 3.83Mb/s]
# Transferring ScenarioList.csv from server
# 100%|##########| 664k/664k [00:00<00:00, 3.12Mb/s]
# Loading bus
# Loading plant
# Loading heat_rate_curve
# Loading gencost_before
# Loading gencost_after
# Loading branch
# Loading dcline
# Loading sub
# Loading bus2sub
# --> Loading ct
# --> Loading PG
# --> Loading solar
# --> Loading wind

# %%
plot_heatmap(
    summed_curtailment,
    cmap="PiYG_r",
    scale=1e-3,
    cbar_label="GW",
    vmin=0,
    vmax=250,
    cbar_tick_values=[0, 50, 100, 150, 200, 250],
    cbar_tick_labels=['0', '50', '100', '150', '200', '≥250'],
    time_zone="ETC/GMT+6",
    time_zone_label="(CST)",
    contour_levels=[250],
)
