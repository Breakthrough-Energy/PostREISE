# %%
from powersimdata import Scenario
from powersimdata.utility.helpers import PrintManager

from postreise.plot.plot_bar_generation_max_min_actual import plot_bar_generation_max_min_actual

# %% [markdown]
# ### Bar plot

# %%
with PrintManager():
    scenario = Scenario(823)
    plot_bar_generation_max_min_actual(scenario, "USA", "coal", show_as_state=True, percentage=False)
    plot_bar_generation_max_min_actual(scenario, "Western", "ng", show_as_state=True, percentage=True)
    plot_bar_generation_max_min_actual(scenario, "Texas", "wind", show_as_state=False, percentage=False)
