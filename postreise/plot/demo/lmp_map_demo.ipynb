# %% [markdown]
# # Locational Marginal Price Map

# %%
from powersimdata.scenario.scenario import Scenario  
from postreise.plot.plot_lmp_map import map_lmp
from bokeh.io import show, output_notebook

# %% [markdown]
# Here, we consider our *2020 base scenario*. This is the scenario presented in the scrolly telling on our webpage: https://science.breakthroughenergy.org/.

# %%
base = Scenario("824")
# Out:
#  54%|#####4    | 360k/664k [00:00<00:00, 3.54Mb/s]
# Transferring ScenarioList.csv from server
# 100%|##########| 664k/664k [00:00<00:00, 3.09Mb/s]
# 100%|##########| 50.0k/50.0k [00:00<00:00, 807kb/s]
# Transferring ExecuteList.csv from server
# SCENARIO: Julia | USABase_2020_Anchor_profile_fix_1
#
# --> State
# analyze
# --> Loading grid
#  59%|#####9    | 393k/664k [00:00<00:00, 3.80Mb/s]
# Transferring ScenarioList.csv from server
# 100%|##########| 664k/664k [00:00<00:00, 3.14Mb/s]
# Loading bus
# Loading plant
# Loading heat_rate_curve
# Loading gencost_before
# Loading gencost_after
# Loading branch
# Loading dcline
# Loading sub
# Loading bus2sub
# --> Loading ct

# %%
lmp_map = map_lmp(base)
output_notebook()
show(lmp_map)
# Out:
# --> Loading LMP
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1045">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="92ddea00-4d0e-466b-bb95-56f06cb1aca0" data-root-id="1001"></div>
