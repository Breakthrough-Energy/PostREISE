# %% [markdown]
# # Tornado Plot
# Tornado plots are great to exhibit relative differences.

# %%
from postreise.plot.plot_tornado import plot_tornado

# %%
# Made up data
title = 'Normalized Coal Cost Differences in Western'
data = {
    'Arizona': 25,
    'California': 8,
    'Colorado': 15,
    'Idaho': 5,
    'Montana Western': 35,
    'Nevada': 1,
    'New Mexico Western': 15,
    'Oregon': 10,
    'Utah': 0,
    'Washington': -15,
    'Wyoming': -6,
    'El Paso': -1
}

# %%
plot_tornado(title, data)

# %% [markdown]
# Sort values from smallest to largest.

# %%
plot_tornado(title, data, sorted=True)
