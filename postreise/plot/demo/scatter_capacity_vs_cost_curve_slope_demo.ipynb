# %%
from powersimdata.utility.helpers import PrintManager
from powersimdata import Scenario

from postreise.plot.plot_scatter_capacity_vs_cost_curve_slope import plot_scatter_capacity_vs_cost_curve_slope

# %% [markdown]
# ### Scatter Plot

# %%
with PrintManager():
    scenario = Scenario("823")

# %%
_, data_avg = plot_scatter_capacity_vs_cost_curve_slope(scenario, "all", "coal")

# %%
data_avg
# Out:
# 33.811286002693414

# %%
_, data_avg = plot_scatter_capacity_vs_cost_curve_slope(scenario, "Eastern", ["coal", "ng"])

# %%
data_avg
# Out:
# 35.998040456752726
